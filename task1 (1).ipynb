# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_2391096.csv',header=2)

# %%
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                2
#                  ...
# 2020                1
# 2021                1
# 2022                1
# 2023                1
# Unnamed: 68       266
# Length: 69, dtype: int64

# %%
data=df.set_index('Country Name').iloc[:,4:].T
data=data.apply(pd.to_numeric,errors='coerce').dropna(how='all')
data
# Out:
# Country Name     Aruba  Africa Eastern and Southern  Afghanistan  \
# 1961           55811.0                  134169237.0    8790140.0
# 1962           56682.0                  137835590.0    8969047.0
# 1963           57475.0                  141630546.0    9157465.0
# 1964           58178.0                  145605995.0    9355514.0
# 1965           58782.0                  149742351.0    9565147.0
# ...                ...                          ...          ...
# 2019          106442.0                  667242986.0   37769499.0
# 2020          106585.0                  685112979.0   38972230.0
# 2021          106537.0                  702977106.0   40099462.0
# 2022          106445.0                  720859132.0   41128771.0
# 2023          106277.0                  739108306.0   42239854.0
#
# Country Name  Africa Western and Central      Angola    Albania  Andorra  \
# 1961                          99314028.0   5441333.0  1659800.0  10216.0
# ...

# %%
total=data.sum(axis=1)
plt.figure(figsize=(15,6))
total.plot(kind='bar')
plt.title('Total Population')
plt.xlabel('Year')
plt.ylabel('Population')
plt.show()

# %%
cols=['1960','1961','1962','1963','1964','1965','1965','1966','1967','1968','1969','197','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980','1981','1982','1983','1984','1985','1986','1987','1988','1989','1990','1991','1992','1993','1994','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021','2022','2023']

# %%
import matplotlib.pyplot as plt
for i in cols:
  fig=plt.figure(figsize=(6,6))
  plt.hist(df[i],bins=10)
  plt.xlabel(i)
  plt.show()

# %%
country_by_1960=df.sort_values(by='1960')
country_by_1960
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 225  Sint Maarten (Dutch part)          SXM  Population, total    SP.POP.TOTL
# 147   St. Martin (French part)          MAF  Population, total    SP.POP.TOTL
# 179                      Nauru          NRU  Population, total    SP.POP.TOTL
# 245                     Tuvalu          TUV  Population, total    SP.POP.TOTL
# 228   Turks and Caicos Islands          TCA  Population, total    SP.POP.TOTL
# ..                         ...          ...                ...            ...
# 140        Low & middle income          LMY  Population, total    SP.POP.TOTL
# 103           IDA & IBRD total          IBT  Population, total    SP.POP.TOTL
# 259                      World          WLD  Population, total    SP.POP.TOTL
# 110             Not classified          INX  Population, total    SP.POP.TOTL
# 196         West Bank and Gaza          PSE  Population, total    SP.POP.TOTL
#
# ...

# %%
ages = [10,15,20,25,30,35,40,45,50,55,60,65,70,75,80]
genders = ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male']

# Create a Pandas DataFrame
df = pd.DataFrame({'Age': ages, 'Gender': genders})

# Create a histogram for the continuous variable (Age)
plt.hist(df['Age'], bins=10, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Ages')
plt.show()
